# %% [markdown]
# <a href="https://colab.research.google.com/github/Santiago-Echeverri-Arteaga/animated-spoon/blob/master/codigo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mi primer Notebook en Colab
#
# ⛴

# %%
print("Hola animated-spoon desde Colab")
# Out:
# Hola animated-spoon desde Colab
