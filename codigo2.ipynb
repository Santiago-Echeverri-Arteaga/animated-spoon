# %% [markdown]
# # Este es mi primer notebook de Python
#
# ## Con comandos markdown

# %%
print("Hola mundo desde un notebook en caracteristicas")
# Out:
# Hola mundo desde un notebook en caracteristicas

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# # Seccion 2
#
# En esta seccion vamos a implementar
#
# $$ y=mx+b$$
# $$y=\frac{mx+b}{ax^2+bx+c}$$

# %%
print("Hello World")
